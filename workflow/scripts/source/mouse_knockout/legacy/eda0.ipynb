# %%
# %load_ext lab_black

# %%
from pathlib import Path

import requests
import pandas as pd

# %%
ag_disease_path = Path("data") / "DISEASE-ALLIANCE_COMBINED_37.tsv"
assert ag_disease_path.exists()

# %%
# !head -n 20 {str(ag_disease_path)}
# Out:
# ##########################################################################
# #
# # Data type: Disease
# # Data format: tsv
# # README:
# # Source: Alliance of Genome Resources (Alliance)
# # Source URL: http://alliancegenome.org/downloads
# # Help Desk: help@alliancegenome.org
# # Orthology Filter: Stringent
# # Taxon IDs: NCBITaxon:9606, NCBITaxon:10116, NCBITaxon:10090, NCBITaxon:7955, NCBITaxon:7227, NCBITaxon:6239, NCBITaxon:559292
# # Species: Homo sapiens, Rattus norvegicus, Mus musculus, Danio rerio, Drosophila melanogaster, Caenorhabditis elegans, Saccharomyces cerevisiae
# # Alliance Database Version: 3.2.0
# # Date file generated (UTC): 2020-10-17 00:46
# #
# ##########################################################################
# Taxon	SpeciesName	DBobjectType	DBObjectID	DBObjectSymbol	AssociationType	DOID	DOtermName	WithOrthologs	InferredFromID	InferredFromSymbol	EvidenceCode	EvidenceCodeName	Reference	Date	Source
# ...

# %%
df_read = pd.read_csv(ag_disease_path, sep="\t", comment="#")
df_read.head()
# Out:
# /home/yiliu/.local/share/virtualenvs/mouse_knockout/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (9,10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             Taxon             SpeciesName DBobjectType         DBObjectID  \
# 0  NCBITaxon:6239  Caenorhabditis elegans         gene  WB:WBGene00013697
# 1  NCBITaxon:6239  Caenorhabditis elegans         gene  WB:WBGene00003163
# 2  NCBITaxon:6239  Caenorhabditis elegans         gene  WB:WBGene00003331
# 3  NCBITaxon:6239  Caenorhabditis elegans         gene  WB:WBGene00003292
# 4  NCBITaxon:6239  Caenorhabditis elegans         gene  WB:WBGene00004208
#
#   DBObjectSymbol   AssociationType        DOID                 DOtermName  \
# 0         dsbn-1  is_implicated_in   DOID:3753  Hermansky-Pudlak syndrome
# 1          mdl-1  is_implicated_in  DOID:14330        Parkinson's disease
# ...

# %%
df_read.to_csv("data/tmp_sanitised.csv", index=False)

# %%
field = "DOID"
print(len(df_read[field]))
print(len(df_read[field].drop_duplicates()))
# Out:
# 236292
# 5186

# %%
field = "DOtermName"
print(len(df_read[field]))
print(len(df_read[field].drop_duplicates()))
# Out:
# 236292
# 5186

# %% [markdown]
# ---

# %%
covid_df = df_read[df_read["DOtermName"] == "COVID-19"]
covid_df
# Out:
#                  Taxon              SpeciesName DBobjectType  \
# 2451    NCBITaxon:6239   Caenorhabditis elegans         gene
# 4850    NCBITaxon:6239   Caenorhabditis elegans         gene
# 5388    NCBITaxon:6239   Caenorhabditis elegans         gene
# 5587    NCBITaxon:6239   Caenorhabditis elegans         gene
# 6675    NCBITaxon:6239   Caenorhabditis elegans         gene
# ...                ...                      ...          ...
# 229765  NCBITaxon:7227  Drosophila melanogaster         gene
# 230058  NCBITaxon:7227  Drosophila melanogaster         gene
# 230630  NCBITaxon:7227  Drosophila melanogaster         gene
# 230696  NCBITaxon:7227  Drosophila melanogaster         gene
# 231825  NCBITaxon:7227  Drosophila melanogaster         gene
#
#                DBObjectID DBObjectSymbol           AssociationType  \
# 2451    WB:WBGene00001501          ftn-2   biomarker_via_orthology
# 4850    WB:WBGene00013969          tep-1  implicated_via_orthology
# ...

# %%
covid_df["DOID"].drop_duplicates()
# Out:
# 2451    DOID:0080600
# Name: DOID, dtype: object

# %%
covid_df["SpeciesName"].value_counts()
# Out:
# Homo sapiens                154
# Mus musculus                116
# Danio rerio                 115
# Rattus norvegicus            99
# Drosophila melanogaster      40
# Caenorhabditis elegans       33
# Saccharomyces cerevisiae      1
# Name: SpeciesName, dtype: int64

# %%
{_: covid_df[_].is_unique for _ in covid_df.columns.values}
# Out:
# {'Taxon': False,
#  'SpeciesName': False,
#  'DBobjectType': False,
#  'DBObjectID': False,
#  'DBObjectSymbol': False,
#  'AssociationType': False,
#  'DOID': False,
#  'DOtermName': False,
#  'WithOrthologs': False,
#  'InferredFromID': False,
#  'InferredFromSymbol': False,
#  'EvidenceCode': False,
#  'EvidenceCodeName': False,
#  'Reference': False,
#  'Date': False,
#  'Source': False}

# %% [markdown]
# ---

# %%
disease_df = df_read[["DOID", "DOtermName"]].drop_duplicates()
disease_df.to_csv("data/disease_df.csv", index=False)
disease_df.head()
# Out:
#             DOID                               DOtermName
# 0      DOID:3753                Hermansky-Pudlak syndrome
# 1     DOID:14330                      Parkinson's disease
# 15    DOID:14499                            Fabry disease
# 16  DOID:0060037  developmental disorder of mental health
# 17    DOID:12704                    ataxia telangiectasia
