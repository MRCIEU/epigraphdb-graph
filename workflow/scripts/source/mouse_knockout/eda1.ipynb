# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
from pprint import pprint

import requests
import pandas as pd

# %%
from extraction import (
    animal_disease_to_genes,
    animal_disease_to_alleles,
    animal_disease_to_models,
)

# %% [markdown]
# ---

# %% [markdown]
# - disease view
#   - COVID-19 https://www.alliancegenome.org/disease/DOID:0080600
#   - coronary artery disease https://www.alliancegenome.org/disease/DOID:3393
# - allele view https://www.alliancegenome.org/allele/MGI:6431336
# - gene view https://www.alliancegenome.org/gene/HGNC:13557
#
# ---
# - ECO evidence & conclusion ontology https://www.ebi.ac.uk/ols/ontologies/eco

# %% [markdown]
# Schema models:
#
# Rels
#
# - `(Disease)`-`[ANIMAL_EVIDENCE_GENE]`->`(AnimalGene)`
#   - association_type
#   - evidence_id
#   - publication_id
# - `(Disease)`-`[ANIMAL_EVIDENCE_ALLELE]`->`(AnimalAllele)`
#   - association_type
#   - evidence_id
#   - publication_id
# - `(Disease)`-`[ANIMAL_EVIDENCE_MODEL]`->`(AnimalModel)`
#   - association_type
#   - evidence_id
#   - publication_id
#
# Nodes
#
# - `(Disease)`, `(Literature)`
# - `(AnimalGene)`, `(AnimalAllele)`, `(AnimalModel)`
#   - {X}_id
#   - {X}_name
#   - {X}_species_id
#   - {X}_species_name
# - `(AnimalEvidence)`
#   - id
#   - name
#   - symbol
# - `(AnimalSpecies)`?
#   - id
#   - name
#     - Homo sapiens
#     - Mus musculus
#     - Rattus norvegicus
#     - Caenorhabditis elegans
#     - Drosophila melanogaster
#     - Danio rerio
#     - Saccharomyces cerevisiae

# %% [markdown]
# TODO:
#
#     - docs on `association_type`
#     - get model "type: genotype"
#     - https://www.mousephenotype.org/; disease - knockout_genes
#     - http://www.informatics.jax.org/downloads/reports/MGI_PhenotypicAllele.rpt; disease - gene; knockout rel prop; double check, x-reference
#     - https://www.mousephenotype.org/data/phenotypes/MP:0000266
#     - http://ftp.ebi.ac.uk/pub/databases/impc/all-data-releases/release-13.0/results/

# %% [markdown]
# ---

# %%
API = "https://www.alliancegenome.org"

DOID = "DOID:0080600"  # COVID-19
DOID1 = "DOID:3393"  # coronary artery disease

# %%
route = "/api/disease/{id}"
r = requests.get(API + route.format(id=DOID))
r.raise_for_status()
disease_info = r.json()

pprint(disease_info)
# Out:
# {'children': None,
#  'crossReferences': {},
#  'definition': 'A Coronavirus infection that is characterized by fever, cough '
#                'and shortness of breath and that has_material_basis_in '
#                'SARS-CoV-2.',
#  'definitionLinks': ['https://www.cdc.gov/coronavirus/2019-ncov/about/index.html',
#                      'https://www.ncbi.nlm.nih.gov/Taxonomy/Browser/wwwtax.cgi?id=2697049',
#                      'https://www.ncbi.nlm.nih.gov/pubmed/?term=32007143',
#                      'https://www.ncbi.nlm.nih.gov/pubmed/?term=32007145',
#                      'https://www.who.int/emergencies/diseases/novel-coronavirus-2019'],
#  'id': 'DOID:0080600',
#  'name': 'COVID-19',
#  'parents': [{'id': 'DOID:0080599', 'name': 'Coronavirus infectious disease'}],
#  'sources': [{'name': 'RGD',
#               'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=All&x=1&acc_id=DOID:0080600#annot'},
#              {'name': 'MGI',
#               'url': 'http://www.informatics.jax.org/disease/DOID:0080600'},
#              {'name': 'ZFIN', 'url': 'https://zfin.org/DOID:0080600'},
#              {'name': 'FB',
#               'url': 'https://flybase.org/cgi-bin/cvreport.html?id=DOID:0080600'},
#              {'name': 'WB',
#               'url': 'https://www.wormbase.org/resources/disease/DOID:0080600'},
#              {'name': 'SGD',
#               'url': 'https://yeastgenome.org/disease/DOID:0080600'}],
#  'synonyms': ['Wuhan coronavirus infection',
#               '2019-nCoV infection',
#               'SARS-CoV-2 infection',
#               'Wuhan seafood market pneumonia virus infection',
#               'COVID19',
#               '2019 Novel Coronavirus (2019-nCoV)'],
#  'url': 'http://www.disease-ontology.org/?id=DOID:0080600'}

# %% [markdown]
# ---

# %% [markdown]
# # Genes

# %%
route = "/api/disease/{id}/genes"
r = requests.get(API + route.format(id=DOID))
r.raise_for_status()
assoc_genes = r.json()["results"]

pprint(assoc_genes)
# Out:
# [{'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:7',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'A2M',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:7DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-08-12T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '1e9330e6-4773-4177-893a-1de4f92c1996',
#                         'publication': {'id': 'PMID:32747830',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}}],
#   'publications': [{'id': 'PMID:32747830',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:79',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'ABO',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:79DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-07-09T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '786477dc-c731-48aa-82b9-0ed8a3ecc8a6',
#                         'publication': {'id': 'PMID:32379894',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32379894'}}],
#   'publications': [{'id': 'PMID:32379894',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32379894'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:2707',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'ACE',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:2707DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': 'bef5e152-6eea-4a49-a02f-dba83f8a8736',
#                         'publication': {'id': 'PMID:32286246',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32286246'}}],
#   'publications': [{'id': 'PMID:32286246',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32286246'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_not_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:2707',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'ACE',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:2707DOID:0080600IS_IMPLICATED_INNOT',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '5a63924c-58aa-406a-a07b-a5572f8b79dd',
#                         'publication': {'id': 'PMID:32386188',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32386188'}}],
#   'publications': [{'id': 'PMID:32386188',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32386188'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IMP',
#                      'id': 'ECO:0000315',
#                      'name': 'mutant phenotype evidence used in manual '
#                              'assertion'},
#                     {'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:13557',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'ACE2',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:13557DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-24T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IMP',
#                                            'id': 'ECO:0000315',
#                                            'name': 'mutant phenotype evidence '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '79227e7b-27d9-483a-8677-6af1bf73372d',
#                         'publication': {'id': 'PMID:32380511',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'}},
#                        {'dateAssigned': '2020-06-28T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '84049e40-4e42-4509-8e59-ee3508aedfec',
#                         'publication': {'id': 'PMID:32220422',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32220422'}}],
#   'publications': [{'id': 'PMID:32220422',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32220422'},
#                    {'id': 'PMID:32380511',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IMP',
#                      'id': 'ECO:0000315',
#                      'name': 'mutant phenotype evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:336',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'AGTR1',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:336DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IMP',
#                                            'id': 'ECO:0000315',
#                                            'name': 'mutant phenotype evidence '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '6f622c20-abfe-450e-a52c-63aa7354288e',
#                         'publication': {'id': 'PMID:32228222',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32228222'}}],
#   'publications': [{'id': 'PMID:32228222',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32228222'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:399',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'ALB',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:399DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-19T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'd8645374-a50a-4d78-9fb4-ed0944b3aac2',
#                         'publication': {'id': 'PMID:32427582',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32427582'}},
#                        {'dateAssigned': '2020-06-16T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'e0a5fc3b-ea73-4a52-ad77-9d6b8c015576',
#                         'publication': {'id': 'PMID:32198776',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32198776'}}],
#   'publications': [{'id': 'PMID:32198776',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32198776'},
#                    {'id': 'PMID:32427582',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32427582'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:485',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'ANGPT2',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:485DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-26T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'be6bd5e9-8f59-4de8-b90e-728c7a9b5d1b',
#                         'publication': {'id': 'PMID:32458111',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32458111'}}],
#   'publications': [{'id': 'PMID:32458111',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32458111'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:1027',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'BDH1',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:1027DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-24T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'f6a850f6-f4e3-42ce-be7a-eab68e5f8c8a',
#                         'publication': {'id': 'PMID:32456948',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32456948'}}],
#   'publications': [{'id': 'PMID:32456948',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32456948'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:1318',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'C3',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:1318DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-24T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '53c343b0-382a-4d33-b041-1970d958b227',
#                         'publication': {'id': 'PMID:32434211',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32434211'}}],
#   'publications': [{'id': 'PMID:32434211',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32434211'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:1318',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'C3',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:1318DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-08-12T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': 'ac2b660c-df5b-4550-93be-930a833c966c',
#                         'publication': {'id': 'PMID:32747830',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}}],
#   'publications': [{'id': 'PMID:32747830',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:1325',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'C4BPA',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:1325DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-08-12T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': '371ce4fd-e30a-4292-91d5-3e98a408260f',
#                         'publication': {'id': 'PMID:32747830',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}}],
#   'publications': [{'id': 'PMID:32747830',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IAGP',
#                      'id': 'ECO:0007191',
#                      'name': 'inference by association of genotype from '
#                              'phenotype used in manual assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:1328',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'C4BPB',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:1328DOID:0080600IS_IMPLICATED_IN',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-08-12T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IAGP',
#                                            'id': 'ECO:0007191',
#                                            'name': 'inference by association '
#                                                    'of genotype from phenotype '
#                                                    'used in manual assertion'}],
#                         'primaryKey': 'a8b17da7-bd43-4601-9aaa-90b706f31c25',
#                         'publication': {'id': 'PMID:32747830',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}}],
#   'publications': [{'id': 'PMID:32747830',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32747830'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:1437',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CALCA',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:1437DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-16T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '49c3ca03-f948-4373-bc21-40abcce90f4c',
#                         'publication': {'id': 'PMID:32198776',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32198776'}},
#                        {'dateAssigned': '2020-06-16T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '4df78a71-2b1e-43b6-93a4-d92dd68cbcda',
#                         'publication': {'id': 'PMID:32220650',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32220650'}},
#                        {'dateAssigned': '2020-06-24T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'a978e2cc-d3da-4008-af33-5bafa8af932d',
#                         'publication': {'id': 'PMID:32365221',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32365221'}},
#                        {'dateAssigned': '2020-06-16T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'fdf80006-ffed-4411-9fee-fb0b1a07fc9e',
#                         'publication': {'id': 'PMID:32345579',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32345579'}}],
#   'publications': [{'id': 'PMID:32198776',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32198776'},
#                    {'id': 'PMID:32220650',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32220650'},
#                    {'id': 'PMID:32345579',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32345579'},
#                    {'id': 'PMID:32365221',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32365221'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:10618',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CCL2',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:10618DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-19T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '4cb68292-e653-42cb-b1ae-ecd790ba49fc',
#                         'publication': {'id': 'PMID:31986264',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/31986264'}},
#                        {'dateAssigned': '2020-06-16T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '71bcd6b9-abab-4061-8035-d618f23b59e7',
#                         'publication': {'id': 'PMID:32416070',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32416070'}},
#                        {'dateAssigned': '2020-08-17T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'a15946f3-e3e3-483e-acab-1a037748bc14',
#                         'publication': {'id': 'PMID:32696007',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32696007'}},
#                        {'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'a577b3c2-96c9-4797-8f04-33676c7e785c',
#                         'publication': {'id': 'PMID:32427582',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32427582'}},
#                        {'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': 'c7ace2f0-5624-4704-9d5e-9e34a5e2aeb1',
#                         'publication': {'id': 'PMID:32360286',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}}],
#   'publications': [{'id': 'PMID:31986264',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/31986264'},
#                    {'id': 'PMID:32360286',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'},
#                    {'id': 'PMID:32416070',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32416070'},
#                    {'id': 'PMID:32427582',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32427582'},
#                    {'id': 'PMID:32696007',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32696007'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:10626',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CCL27',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:10626DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '3d3b9900-4dbd-4a4d-bb43-fd8357dec399',
#                         'publication': {'id': 'PMID:32360286',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}}],
#   'publications': [{'id': 'PMID:32360286',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:10627',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CCL3',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:10627DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '36a72185-77ef-467c-95e5-a8a460793331',
#                         'publication': {'id': 'PMID:32360286',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}},
#                        {'dateAssigned': '2020-06-19T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '657eee67-f0c5-406c-87b7-bdf5f232321a',
#                         'publication': {'id': 'PMID:31986264',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/31986264'}}],
#   'publications': [{'id': 'PMID:31986264',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/31986264'},
#                    {'id': 'PMID:32360286',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:10630',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CCL4',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:10630DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-19T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '328f36d8-77a3-4744-9ced-aab979b9f655',
#                         'publication': {'id': 'PMID:31986264',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/31986264'}},
#                        {'dateAssigned': '2020-08-17T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '7d2b46d2-9cde-4b0a-93d7-445487f44073',
#                         'publication': {'id': 'PMID:32696007',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32696007'}},
#                        {'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '98250069-bfd6-42e6-9fcf-00db94888251',
#                         'publication': {'id': 'PMID:32360286',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}}],
#   'publications': [{'id': 'PMID:31986264',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/31986264'},
#                    {'id': 'PMID:32360286',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'},
#                    {'id': 'PMID:32696007',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32696007'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:10632',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CCL5',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:10632DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '1c89fa06-4b80-4aa0-890f-cd5a3e96df8b',
#                         'publication': {'id': 'PMID:32427582',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32427582'}}],
#   'publications': [{'id': 'PMID:32427582',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32427582'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}},
#  {'allele': None,
#   'associationType': 'is_marker_for',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'IEP',
#                      'id': 'ECO:0000270',
#                      'name': 'expression pattern evidence used in manual '
#                              'assertion'}],
#   'gene': {'crossReferences': {},
#            'id': 'HGNC:10634',
#            'secondaryIds': [],
#            'species': {'commonNames': "['human', 'hsa']",
#                        'dataProviderFullName': 'Rat Genome Database',
#                        'dataProviderShortName': 'RGD',
#                        'name': 'Homo sapiens',
#                        'shortName': 'Hsa',
#                        'taxonId': 'NCBITaxon:9606'},
#            'symbol': 'CCL7',
#            'synonyms': [],
#            'type': 'gene',
#            'url': None},
#   'geneticEntityType': 'gene',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'HGNC:10634DOID:0080600IS_MARKER_FOR',
#   'providers': [{'sourceProvider': {'displayName': 'RGD',
#                                     'name': 'RGD',
#                                     'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}],
#   'publicationJoins': [{'dateAssigned': '2020-06-18T00:00:00.000-05:00',
#                         'evidenceCodes': [{'displaySynonym': 'IEP',
#                                            'id': 'ECO:0000270',
#                                            'name': 'expression pattern '
#                                                    'evidence used in manual '
#                                                    'assertion'}],
#                         'primaryKey': '41f725b5-db48-4eab-ad2c-61cfd87f0c0f',
#                         'publication': {'id': 'PMID:32360286',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}}],
#   'publications': [{'id': 'PMID:32360286',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32360286'}],
#   'references': None,
#   'source': {'name': 'RGD',
#              'url': 'https://rgd.mcw.edu/rgdweb/ontology/annot.html?species=Human&x=1&acc_id=DOID:0080600#annot'}}]

# %%
# diagnostics: evidence is unique
foo = [_["evidenceCodes"] for _ in assoc_genes]
bar = [len(_) != 1 for _ in foo]
print(len(foo))
print(sum(bar))
# Out:
# 20
# 0

# %%
df = animal_disease_to_genes(doid=DOID)

# %%
df
# Out:
#    primary_disease_id    disease_id     gene_id gene_name gene_species_id  \
# 0        DOID:0080600  DOID:0080600      HGNC:7       A2M  NCBITaxon:9606
# 1        DOID:0080600  DOID:0080600     HGNC:79       ABO  NCBITaxon:9606
# 2        DOID:0080600  DOID:0080600   HGNC:2707       ACE  NCBITaxon:9606
# 3        DOID:0080600  DOID:0080600   HGNC:2707       ACE  NCBITaxon:9606
# 4        DOID:0080600  DOID:0080600  HGNC:13557      ACE2  NCBITaxon:9606
# 5        DOID:0080600  DOID:0080600    HGNC:336     AGTR1  NCBITaxon:9606
# 6        DOID:0080600  DOID:0080600    HGNC:399       ALB  NCBITaxon:9606
# 7        DOID:0080600  DOID:0080600    HGNC:485    ANGPT2  NCBITaxon:9606
# 8        DOID:0080600  DOID:0080600   HGNC:1027      BDH1  NCBITaxon:9606
# 9        DOID:0080600  DOID:0080600   HGNC:1318        C3  NCBITaxon:9606
# 10       DOID:0080600  DOID:0080600   HGNC:1318        C3  NCBITaxon:9606
# 11       DOID:0080600  DOID:0080600   HGNC:1325     C4BPA  NCBITaxon:9606
# 12       DOID:0080600  DOID:0080600   HGNC:1328     C4BPB  NCBITaxon:9606
# 13       DOID:0080600  DOID:0080600   HGNC:1437     CALCA  NCBITaxon:9606
# 14       DOID:0080600  DOID:0080600  HGNC:10618      CCL2  NCBITaxon:9606
# 15       DOID:0080600  DOID:0080600  HGNC:10626     CCL27  NCBITaxon:9606
# 16       DOID:0080600  DOID:0080600  HGNC:10627      CCL3  NCBITaxon:9606
# 17       DOID:0080600  DOID:0080600  HGNC:10630      CCL4  NCBITaxon:9606
# 18       DOID:0080600  DOID:0080600  HGNC:10632      CCL5  NCBITaxon:9606
# 19       DOID:0080600  DOID:0080600  HGNC:10634      CCL7  NCBITaxon:9606
#
#    gene_species_name      association_type  \
# 0       Homo sapiens      is_implicated_in
# 1       Homo sapiens      is_implicated_in
# 2       Homo sapiens      is_implicated_in
# 3       Homo sapiens  is_not_implicated_in
# 4       Homo sapiens      is_implicated_in
# 5       Homo sapiens      is_implicated_in
# 6       Homo sapiens         is_marker_for
# 7       Homo sapiens         is_marker_for
# 8       Homo sapiens         is_marker_for
# 9       Homo sapiens         is_marker_for
# 10      Homo sapiens      is_implicated_in
# 11      Homo sapiens      is_implicated_in
# 12      Homo sapiens      is_implicated_in
# 13      Homo sapiens         is_marker_for
# 14      Homo sapiens         is_marker_for
# 15      Homo sapiens         is_marker_for
# 16      Homo sapiens         is_marker_for
# 17      Homo sapiens         is_marker_for
# 18      Homo sapiens         is_marker_for
# 19      Homo sapiens         is_marker_for
#
#                                              evidence  \
# 0   [{'id': 'ECO:0007191', 'name': 'inference by a...
# 1   [{'id': 'ECO:0007191', 'name': 'inference by a...
# 2   [{'id': 'ECO:0007191', 'name': 'inference by a...
# 3   [{'id': 'ECO:0007191', 'name': 'inference by a...
# 4   [{'id': 'ECO:0000315', 'name': 'mutant phenoty...
# 5   [{'id': 'ECO:0000315', 'name': 'mutant phenoty...
# 6   [{'id': 'ECO:0000270', 'name': 'expression pat...
# 7   [{'id': 'ECO:0000270', 'name': 'expression pat...
# 8   [{'id': 'ECO:0000270', 'name': 'expression pat...
# 9   [{'id': 'ECO:0000270', 'name': 'expression pat...
# 10  [{'id': 'ECO:0007191', 'name': 'inference by a...
# 11  [{'id': 'ECO:0007191', 'name': 'inference by a...
# 12  [{'id': 'ECO:0007191', 'name': 'inference by a...
# 13  [{'id': 'ECO:0000270', 'name': 'expression pat...
# 14  [{'id': 'ECO:0000270', 'name': 'expression pat...
# 15  [{'id': 'ECO:0000270', 'name': 'expression pat...
# 16  [{'id': 'ECO:0000270', 'name': 'expression pat...
# 17  [{'id': 'ECO:0000270', 'name': 'expression pat...
# 18  [{'id': 'ECO:0000270', 'name': 'expression pat...
# 19  [{'id': 'ECO:0000270', 'name': 'expression pat...
#
#                                        publication_id
# 0                                     [PMID:32747830]
# 1                                     [PMID:32379894]
# 2                                     [PMID:32286246]
# 3                                     [PMID:32386188]
# 4                      [PMID:32220422, PMID:32380511]
# 5                                     [PMID:32228222]
# 6                      [PMID:32198776, PMID:32427582]
# 7                                     [PMID:32458111]
# 8                                     [PMID:32456948]
# 9                                     [PMID:32434211]
# 10                                    [PMID:32747830]
# 11                                    [PMID:32747830]
# 12                                    [PMID:32747830]
# 13  [PMID:32198776, PMID:32220650, PMID:32345579, ...
# 14  [PMID:31986264, PMID:32360286, PMID:32416070, ...
# 15                                    [PMID:32360286]
# 16                     [PMID:31986264, PMID:32360286]
# 17      [PMID:31986264, PMID:32360286, PMID:32696007]
# 18                                    [PMID:32427582]
# 19                                    [PMID:32360286]

# %%
df["gene_species_name"].value_counts()
# Out:
# Homo sapiens    20
# Name: gene_species_name, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Alleles

# %%
route = "/api/disease/{id}/alleles"
r = requests.get(API + route.format(id=DOID))
r.raise_for_status()
assoc_alleles = r.json()["results"]

pprint(assoc_alleles)
# Out:
# [{'allele': {'category': 'allele',
#              'crossReferences': {'primary': {'displayName': 'MGI:6431336',
#                                              'name': 'MGI:6431336',
#                                              'url': 'http://www.informatics.jax.org/allele/MGI:6431336'},
#                                  'references': {'displayName': 'MGI:6431336',
#                                                 'name': 'MGI:6431336',
#                                                 'url': 'http://www.informatics.jax.org/reference/allele/MGI:6431336?typeFilter=Literature'}},
#              'hasDisease': False,
#              'hasPhenotype': False,
#              'id': 'MGI:6431336',
#              'secondaryIds': [],
#              'species': {'commonNames': "['mouse', 'mmu']",
#                          'dataProviderFullName': 'Mouse Genome Informatics',
#                          'dataProviderShortName': 'MGI',
#                          'name': 'Mus musculus',
#                          'shortName': 'Mmu',
#                          'taxonId': 'NCBITaxon:10090'},
#              'symbol': 'Ace2<sup>em1(ACE2)Yowa</sup>',
#              'symbolText': 'Ace2<em1(ACE2)Yowa>',
#              'synonyms': [],
#              'type': 'allele',
#              'url': 'http://www.informatics.jax.org/allele/MGI:6431336'},
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'TAS',
#                      'id': 'ECO:0000033',
#                      'name': 'author statement supported by traceable '
#                              'reference'}],
#   'gene': None,
#   'geneticEntityType': 'allele',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': [{'alleles': None,
#                                 'crossReference': None,
#                                 'diseaseAssociationType': 'IS_IMPLICATED_IN',
#                                 'diseaseModels': None,
#                                 'displayName': 'Ace2<em1(ACE2)Yowa>/Ace2<em1(ACE2)Yowa> '
#                                                '[background:] '
#                                                'C57BL/6-Ace2<em1(ACE2)Yowa>',
#                                 'id': 'MGI:6431340',
#                                 'name': 'Ace2<sup>em1(ACE2)Yowa</sup>/Ace2<sup>em1(ACE2)Yowa</sup> '
#                                         '[background:] '
#                                         'C57BL/6-Ace2<sup>em1(ACE2)Yowa</sup>',
#                                 'phenotypes': None,
#                                 'publicationEvidenceCodes': [{'dateAssigned': '2020-08-24T11:54:04-04:00',
#                                                               'evidenceCodes': [{'displaySynonym': 'TAS',
#                                                                                  'id': 'ECO:0000033',
#                                                                                  'name': 'author '
#                                                                                          'statement '
#                                                                                          'supported '
#                                                                                          'by '
#                                                                                          'traceable '
#                                                                                          'reference'}],
#                                                               'primaryKey': '235e63de-a504-4e74-9ce7-cd4b0655a73a',
#                                                               'publication': {'id': 'PMID:32485164',
#                                                                               'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32485164'}}],
#                                 'sequenceTargetingReagents': None,
#                                 'source': None,
#                                 'species': None,
#                                 'type': 'GENOTYPE',
#                                 'url': 'http://www.informatics.jax.org/allele/genoview/MGI:6431340'}],
#   'primaryKey': 'MGI:6431336DOID:0080600IS_IMPLICATED_IN',
#   'providers': None,
#   'publicationJoins': [{'dateAssigned': '2020-08-24T11:54:04-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': '235e63de-a504-4e74-9ce7-cd4b0655a73a',
#                         'publication': {'id': 'PMID:32485164',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32485164'}}],
#   'publications': [{'id': 'PMID:32485164',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32485164'}],
#   'references': None,
#   'source': {'name': 'MGI',
#              'url': 'http://www.informatics.jax.org/disease/DOID:0080600'}},
#  {'allele': {'category': 'allele',
#              'crossReferences': {'primary': {'displayName': 'MGI:6401292',
#                                              'name': 'MGI:6401292',
#                                              'url': 'http://www.informatics.jax.org/allele/MGI:6401292'},
#                                  'references': {'displayName': 'MGI:6401292',
#                                                 'name': 'MGI:6401292',
#                                                 'url': 'http://www.informatics.jax.org/reference/allele/MGI:6401292?typeFilter=Literature'}},
#              'hasDisease': False,
#              'hasPhenotype': False,
#              'id': 'MGI:6401292',
#              'secondaryIds': [],
#              'species': {'commonNames': "['mouse', 'mmu']",
#                          'dataProviderFullName': 'Mouse Genome Informatics',
#                          'dataProviderShortName': 'MGI',
#                          'name': 'Mus musculus',
#                          'shortName': 'Mmu',
#                          'taxonId': 'NCBITaxon:10090'},
#              'symbol': 'Tg(Ace2-ACE2)1Cqin',
#              'symbolText': 'Tg(Ace2-ACE2)1Cqin',
#              'synonyms': [],
#              'type': 'allele',
#              'url': 'http://www.informatics.jax.org/allele/MGI:6401292'},
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'TAS',
#                      'id': 'ECO:0000033',
#                      'name': 'author statement supported by traceable '
#                              'reference'}],
#   'gene': None,
#   'geneticEntityType': 'allele',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': [{'alleles': None,
#                                 'crossReference': None,
#                                 'diseaseAssociationType': 'IS_IMPLICATED_IN',
#                                 'diseaseModels': None,
#                                 'displayName': 'Tg(Ace2-ACE2)1Cqin/? '
#                                                '[background:] involves: ICR',
#                                 'id': 'MGI:6402641',
#                                 'name': 'Tg(Ace2-ACE2)1Cqin/? [background:] '
#                                         'involves: ICR',
#                                 'phenotypes': None,
#                                 'publicationEvidenceCodes': [{'dateAssigned': '2020-06-09T00:00:00-04:00',
#                                                               'evidenceCodes': [{'displaySynonym': 'TAS',
#                                                                                  'id': 'ECO:0000033',
#                                                                                  'name': 'author '
#                                                                                          'statement '
#                                                                                          'supported '
#                                                                                          'by '
#                                                                                          'traceable '
#                                                                                          'reference'}],
#                                                               'primaryKey': 'a473a9f5-f489-416b-8350-3ffc2a0b3023',
#                                                               'publication': {'id': 'PMID:32380511',
#                                                                               'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'}},
#                                                              {'dateAssigned': '2020-06-09T00:00:00-04:00',
#                                                               'evidenceCodes': [{'displaySynonym': 'TAS',
#                                                                                  'id': 'ECO:0000033',
#                                                                                  'name': 'author '
#                                                                                          'statement '
#                                                                                          'supported '
#                                                                                          'by '
#                                                                                          'traceable '
#                                                                                          'reference'}],
#                                                               'primaryKey': '24dec14e-abfb-444a-a7b5-b887eee8ca17',
#                                                               'publication': {'id': 'PMID:32444876',
#                                                                               'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32444876'}}],
#                                 'sequenceTargetingReagents': None,
#                                 'source': None,
#                                 'species': None,
#                                 'type': 'GENOTYPE',
#                                 'url': 'http://www.informatics.jax.org/allele/genoview/MGI:6402641'}],
#   'primaryKey': 'MGI:6401292DOID:0080600IS_IMPLICATED_IN',
#   'providers': None,
#   'publicationJoins': [{'dateAssigned': '2020-06-09T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': '24dec14e-abfb-444a-a7b5-b887eee8ca17',
#                         'publication': {'id': 'PMID:32444876',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32444876'}},
#                        {'dateAssigned': '2020-06-09T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': '2f7d4e32-4640-4181-8cd7-6528d1ccdc1f',
#                         'publication': {'id': 'PMID:32498696',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32498696'}},
#                        {'dateAssigned': '2020-06-09T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': 'a473a9f5-f489-416b-8350-3ffc2a0b3023',
#                         'publication': {'id': 'PMID:32380511',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'}}],
#   'publications': [{'id': 'PMID:32380511',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'},
#                    {'id': 'PMID:32444876',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32444876'},
#                    {'id': 'PMID:32498696',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32498696'}],
#   'references': None,
#   'source': {'name': 'MGI',
#              'url': 'http://www.informatics.jax.org/disease/DOID:0080600'}},
#  {'allele': {'category': 'allele',
#              'crossReferences': {'primary': {'displayName': 'MGI:6415223',
#                                              'name': 'MGI:6415223',
#                                              'url': 'http://www.informatics.jax.org/allele/MGI:6415223'},
#                                  'references': {'displayName': 'MGI:6415223',
#                                                 'name': 'MGI:6415223',
#                                                 'url': 'http://www.informatics.jax.org/reference/allele/MGI:6415223?typeFilter=Literature'}},
#              'hasDisease': False,
#              'hasPhenotype': False,
#              'id': 'MGI:6415223',
#              'secondaryIds': [],
#              'species': {'commonNames': "['mouse', 'mmu']",
#                          'dataProviderFullName': 'Mouse Genome Informatics',
#                          'dataProviderShortName': 'MGI',
#                          'name': 'Mus musculus',
#                          'shortName': 'Mmu',
#                          'taxonId': 'NCBITaxon:10090'},
#              'symbol': 'Tg(FOXJ1-ACE2)1Rba',
#              'symbolText': 'Tg(FOXJ1-ACE2)1Rba',
#              'synonyms': [],
#              'type': 'allele',
#              'url': 'http://www.informatics.jax.org/allele/MGI:6415223'},
#   'associationType': 'is_implicated_in',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'TAS',
#                      'id': 'ECO:0000033',
#                      'name': 'author statement supported by traceable '
#                              'reference'}],
#   'gene': None,
#   'geneticEntityType': 'allele',
#   'model': None,
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': [{'alleles': None,
#                                 'crossReference': None,
#                                 'diseaseAssociationType': 'IS_IMPLICATED_IN',
#                                 'diseaseModels': None,
#                                 'displayName': 'Tg(FOXJ1-ACE2)1Rba/? '
#                                                '[background:] involves: C3H * '
#                                                'C57BL/6',
#                                 'id': 'MGI:6415340',
#                                 'name': 'Tg(FOXJ1-ACE2)1Rba/? [background:] '
#                                         'involves: C3H * C57BL/6',
#                                 'phenotypes': None,
#                                 'publicationEvidenceCodes': [{'dateAssigned': '2020-06-09T00:00:00-04:00',
#                                                               'evidenceCodes': [{'displaySynonym': 'TAS',
#                                                                                  'id': 'ECO:0000033',
#                                                                                  'name': 'author '
#                                                                                          'statement '
#                                                                                          'supported '
#                                                                                          'by '
#                                                                                          'traceable '
#                                                                                          'reference'}],
#                                                               'primaryKey': 'cbd7c6d4-3496-4ec5-9ec6-008a4e8d17df',
#                                                               'publication': {'id': 'PMID:32516571',
#                                                                               'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32516571'}}],
#                                 'sequenceTargetingReagents': None,
#                                 'source': None,
#                                 'species': None,
#                                 'type': 'GENOTYPE',
#                                 'url': 'http://www.informatics.jax.org/allele/genoview/MGI:6415340'}],
#   'primaryKey': 'MGI:6415223DOID:0080600IS_IMPLICATED_IN',
#   'providers': None,
#   'publicationJoins': [{'dateAssigned': '2020-06-09T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': '87e1695a-4ddc-4c15-a918-ac646a23f2a9',
#                         'publication': {'id': 'PMID:32498696',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32498696'}},
#                        {'dateAssigned': '2020-06-09T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': 'cbd7c6d4-3496-4ec5-9ec6-008a4e8d17df',
#                         'publication': {'id': 'PMID:32516571',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32516571'}}],
#   'publications': [{'id': 'PMID:32498696',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32498696'},
#                    {'id': 'PMID:32516571',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32516571'}],
#   'references': None,
#   'source': {'name': 'MGI',
#              'url': 'http://www.informatics.jax.org/disease/DOID:0080600'}}]

# %%
df = animal_disease_to_alleles(doid=DOID)
df
# Out:
#   primary_disease_id    disease_id    allele_id          allele_name  \
# 0       DOID:0080600  DOID:0080600  MGI:6431336  Ace2<em1(ACE2)Yowa>
# 1       DOID:0080600  DOID:0080600  MGI:6401292   Tg(Ace2-ACE2)1Cqin
# 2       DOID:0080600  DOID:0080600  MGI:6415223   Tg(FOXJ1-ACE2)1Rba
#
#   allele_species_id allele_species_name  association_type  \
# 0   NCBITaxon:10090        Mus musculus  is_implicated_in
# 1   NCBITaxon:10090        Mus musculus  is_implicated_in
# 2   NCBITaxon:10090        Mus musculus  is_implicated_in
#
#                                             evidence  \
# 0  [{'id': 'ECO:0000033', 'name': 'author stateme...
# 1  [{'id': 'ECO:0000033', 'name': 'author stateme...
# 2  [{'id': 'ECO:0000033', 'name': 'author stateme...
#
#                                   publication_id
# 0                                [PMID:32485164]
# 1  [PMID:32380511, PMID:32444876, PMID:32498696]
# 2                 [PMID:32498696, PMID:32516571]

# %% [markdown]
# ---

# %% [markdown]
# # Models

# %%
route = "/api/disease/{id}/models"
r = requests.get(API + route.format(id=DOID))
r.raise_for_status()
models = r.json()["results"]

pprint(models)
# Out:
# [{'allele': None,
#   'associationType': 'IS_MODEL_OF',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'TAS',
#                      'id': 'ECO:0000033',
#                      'name': 'author statement supported by traceable '
#                              'reference'}],
#   'gene': None,
#   'geneticEntityType': 'gene',
#   'model': {'crossReferences': {},
#             'id': 'MGI:6431340',
#             'modCrossRefCompleteUrl': 'http://www.informatics.jax.org/allele/genoview/MGI:6431340',
#             'name': 'Ace2<sup>em1(ACE2)Yowa</sup>/Ace2<sup>em1(ACE2)Yowa</sup> '
#                     '[background:] C57BL/6-Ace2<sup>em1(ACE2)Yowa</sup>',
#             'nameText': 'Ace2<em1(ACE2)Yowa>/Ace2<em1(ACE2)Yowa> [background:] '
#                         'C57BL/6-Ace2<em1(ACE2)Yowa>',
#             'secondaryIds': [],
#             'species': {'commonNames': "['mouse', 'mmu']",
#                         'dataProviderFullName': 'Mouse Genome Informatics',
#                         'dataProviderShortName': 'MGI',
#                         'name': 'Mus musculus',
#                         'shortName': 'Mmu',
#                         'taxonId': 'NCBITaxon:10090'},
#             'symbol': None,
#             'synonyms': [],
#             'type': 'genotype',
#             'url': None},
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'MGI:6431340DOID:0080600IS_MODEL_OF',
#   'providers': None,
#   'publicationJoins': [{'dateAssigned': '2020-06-03T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': 'a3818290-f625-4021-a364-34df3f4873c1',
#                         'publication': {'id': 'PMID:32485164',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32485164'}}],
#   'publications': [{'id': 'PMID:32485164',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32485164'}],
#   'references': None,
#   'source': {'name': 'MGI', 'url': None}},
#  {'allele': None,
#   'associationType': 'IS_MODEL_OF',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'TAS',
#                      'id': 'ECO:0000033',
#                      'name': 'author statement supported by traceable '
#                              'reference'}],
#   'gene': None,
#   'geneticEntityType': 'gene',
#   'model': {'crossReferences': {},
#             'id': 'MGI:6402641',
#             'modCrossRefCompleteUrl': 'http://www.informatics.jax.org/allele/genoview/MGI:6402641',
#             'name': 'Tg(Ace2-ACE2)1Cqin/? [background:] involves: ICR',
#             'nameText': 'Tg(Ace2-ACE2)1Cqin/? [background:] involves: ICR',
#             'secondaryIds': [],
#             'species': {'commonNames': "['mouse', 'mmu']",
#                         'dataProviderFullName': 'Mouse Genome Informatics',
#                         'dataProviderShortName': 'MGI',
#                         'name': 'Mus musculus',
#                         'shortName': 'Mmu',
#                         'taxonId': 'NCBITaxon:10090'},
#             'symbol': None,
#             'synonyms': [],
#             'type': 'genotype',
#             'url': None},
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'MGI:6402641DOID:0080600IS_MODEL_OF',
#   'providers': None,
#   'publicationJoins': [{'dateAssigned': '2020-04-03T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': 'a87b4872-4ccf-4f48-9f2e-201565083bf6',
#                         'publication': {'id': 'PMID:32444876',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32444876'}},
#                        {'dateAssigned': '2020-04-03T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': 'edfaebf4-af01-4bd7-9107-3b9b7634e6f2',
#                         'publication': {'id': 'PMID:32380511',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'}}],
#   'publications': [{'id': 'PMID:32380511',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32380511'},
#                    {'id': 'PMID:32444876',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32444876'}],
#   'references': None,
#   'source': {'name': 'MGI', 'url': None}},
#  {'allele': None,
#   'associationType': 'IS_MODEL_OF',
#   'disease': {'id': 'DOID:0080600',
#               'name': 'COVID-19',
#               'url': 'http://www.disease-ontology.org/?id=DOID:0080600'},
#   'evidenceCodes': [{'displaySynonym': 'TAS',
#                      'id': 'ECO:0000033',
#                      'name': 'author statement supported by traceable '
#                              'reference'}],
#   'gene': None,
#   'geneticEntityType': 'gene',
#   'model': {'crossReferences': {},
#             'id': 'MGI:6415340',
#             'modCrossRefCompleteUrl': 'http://www.informatics.jax.org/allele/genoview/MGI:6415340',
#             'name': 'Tg(FOXJ1-ACE2)1Rba/? [background:] involves: C3H * '
#                     'C57BL/6',
#             'nameText': 'Tg(FOXJ1-ACE2)1Rba/? [background:] involves: C3H * '
#                         'C57BL/6',
#             'secondaryIds': [],
#             'species': {'commonNames': "['mouse', 'mmu']",
#                         'dataProviderFullName': 'Mouse Genome Informatics',
#                         'dataProviderShortName': 'MGI',
#                         'name': 'Mus musculus',
#                         'shortName': 'Mmu',
#                         'taxonId': 'NCBITaxon:10090'},
#             'symbol': None,
#             'synonyms': [],
#             'type': 'genotype',
#             'url': None},
#   'orthologyGenes': None,
#   'primaryAnnotatedEntities': None,
#   'primaryKey': 'MGI:6415340DOID:0080600IS_MODEL_OF',
#   'providers': None,
#   'publicationJoins': [{'dateAssigned': '2020-06-08T00:00:00-04:00',
#                         'evidenceCodes': [{'displaySynonym': 'TAS',
#                                            'id': 'ECO:0000033',
#                                            'name': 'author statement supported '
#                                                    'by traceable reference'}],
#                         'primaryKey': 'e9d5559d-97bb-4ec3-b203-c94e9d1522bc',
#                         'publication': {'id': 'PMID:32516571',
#                                         'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32516571'}}],
#   'publications': [{'id': 'PMID:32516571',
#                     'url': 'https://www.ncbi.nlm.nih.gov/pubmed/32516571'}],
#   'references': None,
#   'source': {'name': 'MGI', 'url': None}}]

# %%
df = animal_disease_to_models(doid=DOID)
df
# Out:
#   primary_disease_id    disease_id     model_id  \
# 0       DOID:0080600  DOID:0080600  MGI:6431340
# 1       DOID:0080600  DOID:0080600  MGI:6402641
# 2       DOID:0080600  DOID:0080600  MGI:6415340
#
#                                           model_name model_species_id  \
# 0  Ace2<em1(ACE2)Yowa>/Ace2<em1(ACE2)Yowa> [backg...  NCBITaxon:10090
# 1   Tg(Ace2-ACE2)1Cqin/? [background:] involves: ICR  NCBITaxon:10090
# 2  Tg(FOXJ1-ACE2)1Rba/? [background:] involves: C...  NCBITaxon:10090
#
#   model_species_name association_type  \
# 0       Mus musculus      IS_MODEL_OF
# 1       Mus musculus      IS_MODEL_OF
# 2       Mus musculus      IS_MODEL_OF
#
#                                             evidence  \
# 0  [{'id': 'ECO:0000033', 'name': 'author stateme...
# 1  [{'id': 'ECO:0000033', 'name': 'author stateme...
# 2  [{'id': 'ECO:0000033', 'name': 'author stateme...
#
#                    publication_id
# 0                 [PMID:32485164]
# 1  [PMID:32380511, PMID:32444876]
# 2                 [PMID:32516571]
